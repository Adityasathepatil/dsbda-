# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('D:\\third year\\Sem 6\\dsbda\\practical\\datasets\\heart.csv')

# %%
df['Sex']=df['Sex'].replace({1:"Male",0:"Female"})
df
# Out:
#      Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    Male       typical     145   233    1        2    150      0
# 1     67    Male  asymptomatic     160   286    0        2    108      1
# 2     67    Male  asymptomatic     120   229    0        2    129      1
# 3     37    Male    nonanginal     130   250    0        0    187      0
# 4     41  Female    nontypical     130   204    0        2    172      0
# ..   ...     ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    Male       typical     110   264    0        0    132      0
# 299   68    Male  asymptomatic     144   193    1        0    141      0
# 300   57    Male  asymptomatic     130   131    0        0    115      1
# 301   57  Female    nontypical     130   236    0        2    174      0
# 302   38    Male    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df=df.drop('Unnamed: 0',axis=1) #dropping unnamed as its not useful

# %%
# a)Hitsgram
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df["Age"])
# Out:
# (array([ 1., 10., 33., 38., 37., 60., 64., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
# b) Bar Chart
sns.barplot(x='ChestPain', y= "Age", data=df, ci=None, hue = "Sex") #ci=None for hiding top lines
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Age'>

# %%
sns.barplot(x='ChestPain', y= "Age", data=df, ci=None, color = "Yellow" , edgecolor = "Red" ,lw = 2) #lw for edge color
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Age'>

# %%
# c) Pie Chart
f,ax=plt.subplots(1,2,figsize=(10,6))
df["AHD"].value_counts().plot.pie(ax = ax[0],autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='AHD'>

# %%
# d) Box Plot
sns.boxplot(x='AHD', y='Oldpeak', data=df)
# Out:
# <AxesSubplot:xlabel='AHD', ylabel='Oldpeak'>

# %%
fig=plt.figure(figsize=(20,10))
sns.boxplot(data = df,linewidth = 2.5)
plt.show()

# %%
# e) heatmap
corr = df.corr()
corr #Pandas dataframe.corr() is used to find the pairwise correlation of all columns in the dataframe. Any na values are 
#automatically excluded. For any non-numeric data type columns in the dataframe it is ignored.
# Out:
#               Age    RestBP      Chol       Fbs   RestECG     MaxHR     ExAng  \
# Age      1.000000  0.284946  0.208950  0.118530  0.148868 -0.393806  0.091661
# RestBP   0.284946  1.000000  0.130120  0.175340  0.146560 -0.045351  0.064762
# Chol     0.208950  0.130120  1.000000  0.009841  0.171043 -0.003432  0.061310
# Fbs      0.118530  0.175340  0.009841  1.000000  0.069564 -0.007854  0.025665
# RestECG  0.148868  0.146560  0.171043  0.069564  1.000000 -0.083389  0.084867
# MaxHR   -0.393806 -0.045351 -0.003432 -0.007854 -0.083389  1.000000 -0.378103
# ExAng    0.091661  0.064762  0.061310  0.025665  0.084867 -0.378103  1.000000
# Oldpeak  0.203805  0.189171  0.046564  0.005747  0.114133 -0.343085  0.288223
# Slope    0.161770  0.117382 -0.004062  0.059894  0.133946 -0.385601  0.257748
# Ca       0.362605  0.098773  0.119000  0.145478  0.128343 -0.264246  0.145570
#
#           Oldpeak     Slope        Ca
# Age      0.203805  0.161770  0.362605
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr,annot= True)
# Out:
# <AxesSubplot:>

# %%
# scatter plot
sns.scatterplot(df.Age,df.MaxHR)
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='MaxHR'>

# %%
sns.scatterplot(x="Age",y="MaxHR",hue="Oldpeak", data=df, palette="hot")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='MaxHR'>

# %%
sns.boxplot(x='AHD', y='Oldpeak', hue = "Sex", data=df)
# Out:
# <AxesSubplot:xlabel='AHD', ylabel='Oldpeak'>

# %%
plt.pie([20,30])
# Out:
# ([<matplotlib.patches.Wedge at 0x2261893f2b0>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-0.3399185762739153, -1.046162206115244, '')])

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>
